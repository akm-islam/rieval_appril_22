# %%
import pandas as pd
import glob

# %%
a=["CordAscent","LambdaMART","LambdaRank","LinearReg","ListNet","MART","RandomFor","RankBoost","RankNet"]
b=[
"./chart1_data.csv",
"./chart2_data.csv",
"./chart3_data.csv",
"./chart4_data.csv",
"./chart5_data.csv",
"./chart6_data.csv",
"./chart7_data.csv",
"./chart8_data.csv",
"./chart9_data.csv",
]

# %%
temp=[]
for i in range(9):   
    try:
        df=pd.read_csv(b[i],index_col=0)
        df['model']=a[i]
        temp.append(df)
    except:
        print(i)

# %%
merged=pd.concat(temp);

# %% [markdown]
# # Remove extra columns

# %%
for j in merged.columns:
    if "feature_rank" in j:
        merged.drop(j,axis=1,inplace=True)

# %%
for j in merged.columns:
    if j in a:
        merged.drop(j,axis=1,inplace=True)

# %%
merged.columns
# Out:
# Index(['1-qid', 'two_realRank', 'two_realRank2', 'State', 'Cord.Ascent',
#        '1stFlrSF_contribution', '2ndFlrSF_contribution',
#        '3SsnPorch_contribution', 'Alley_contribution',
#        'BedroomAbvGr_contribution', 'BldgType_contribution',
#        'BsmtCond_contribution', 'BsmtExposure_contribution',
#        'BsmtFinSF1_contribution', 'BsmtFinSF2_contribution',
#        'BsmtFinType1_contribution', 'BsmtFinType2_contribution',
#        'BsmtFullBath_contribution', 'BsmtHalfBath_contribution',
#        'BsmtQual_contribution', 'BsmtUnfSF_contribution',
#        'CentralAir_contribution', 'Condition1_contribution',
#        'Condition2_contribution', 'Electrical_contribution',
#        'EnclosedPorch_contribution', 'ExterCond_contribution',
#        'ExterQual_contribution', 'Exterior1st_contribution',
#        'Exterior2nd_contribution', 'Fence_contribution',
#        'FireplaceQu_contribution', 'Fireplaces_contribution',
#        'Foundation_contribution', 'FullBath_contribution',
#        'Functional_contribution', 'GarageArea_contribution',
#        'GarageCars_contribution', 'GarageCond_contribution',
#        'GarageFinish_contribution', 'GarageQual_contribution',
#        'GarageType_contribution', 'GarageYrBlt_contribution',
#        'GrLivArea_contribution', 'HalfBath_contribution',
#        'Heating_contribution', 'HeatingQC_contribution',
#        'HouseStyle_contribution', 'KitchenAbvGr_contribution',
#        'KitchenQual_contribution', 'LandContour_contribution',
#        'LandSlope_contribution', 'LotArea_contribution',
#        'LotConfig_contribution', 'LotFrontage_contribution',
#        'LotShape_contribution', 'LowQualFinSF_contribution',
#        'MSSubClass_contribution', 'MSZoning_contribution',
#        'MasVnrArea_contribution', 'MasVnrType_contribution',
#        'MiscFeature_contribution', 'MiscVal_contribution',
#        'MoSold_contribution', 'Neighborhood_contribution',
#        'OpenPorchSF_contribution', 'OverallCond_contribution',
#        'OverallQual_contribution', 'PavedDrive_contribution',
#        'PoolArea_contribution', 'PoolQC_contribution', 'RoofMatl_contribution',
#        'RoofStyle_contribution', 'SaleCondition_contribution',
#        'SaleType_contribution', 'ScreenPorch_contribution',
#        'Street_contribution', 'TotRmsAbvGrd_contribution',
#        'TotalBsmtSF_contribution', 'Utilities_contribution',
#        'WoodDeckSF_contribution', 'YearBuilt_contribution',
#        'YearRemodAdd_contribution', 'model', 'LinearReg.'],
#       dtype='object')

# %%
merged
# Out:
#       1-qid  two_realRank  two_realRank2  State  Cord.Ascent  \
# 0      2006           169            169      4        239.0
# 1      2006            13             13     12         36.0
# 2      2006           245            245     18        228.0
# 3      2006            17             17     21         69.0
# 4      2006            70             70     29        174.0
# ...     ...           ...            ...    ...          ...
# 1115   2010           111            111   1429          NaN
# 1116   2010            74             74   1439          NaN
# 1117   2010            39             39   1457          NaN
# 1118   2010            17             17   1458          NaN
# 1119   2010            84             84   1459          NaN
#
#       1stFlrSF_contribution  2ndFlrSF_contribution  3SsnPorch_contribution  \
# 0                 -0.000778               0.000473                0.000282
# 1                  0.000131              -0.000233               -0.001162
# 2                 -0.000185               0.000172                0.000963
# 3                 -0.000198               0.000386                0.001099
# 4                  0.002655              -0.000297               -0.002081
# ...                     ...                    ...                     ...
# 1115               0.000094              -0.000009                0.000828
# 1116               0.000021               0.000097                0.001120
# 1117              -0.000136               0.000110                0.000977
# 1118               0.000028              -0.000048                0.001077
# 1119              -0.000002              -0.000002                0.000890
#
#       Alley_contribution  BedroomAbvGr_contribution  ...  \
# 0               0.000327                   0.001093  ...
# 1               0.001845                   0.002616  ...
# 2               0.000451                  -0.002167  ...
# 3               0.000351                   0.003527  ...
# 4               0.001088                  -0.003805  ...
# ...                  ...                        ...  ...
# 1115           -0.000105                  -0.000131  ...
# 1116            0.000043                  -0.000160  ...
# 1117           -0.000030                   0.000060  ...
# 1118            0.000041                   0.000211  ...
# 1119           -0.000012                  -0.000108  ...
#
#       ScreenPorch_contribution  Street_contribution  \
# 0                     0.003305             0.000356
# 1                     0.002480            -0.001419
# 2                     0.002882             0.002967
# 3                     0.003650            -0.000988
# 4                     0.003847             0.003117
# ...                        ...                  ...
# 1115                 -0.000664            -0.000231
# 1116                 -0.000701            -0.000098
# 1117                 -0.000704             0.000411
# 1118                 -0.000691             0.000003
# 1119                 -0.000604             0.000198
#
#       TotRmsAbvGrd_contribution  TotalBsmtSF_contribution  \
# 0                      0.000460                 -0.000244
# 1                      0.010805                  0.000752
# 2                     -0.001885                 -0.001194
# 3                      0.005079                 -0.000999
# 4                     -0.001229                  0.000442
# ...                         ...                       ...
# 1115                   0.000209                 -0.000009
# 1116                   0.000033                  0.000069
# 1117                  -0.000056                 -0.000043
# 1118                  -0.000200                  0.000026
# 1119                   0.000189                 -0.000007
#
#       Utilities_contribution  WoodDeckSF_contribution  YearBuilt_contribution  \
# 0                        0.0                 0.008480               -0.000738
# 1                        0.0                -0.001447                0.000486
# 2                        0.0                 0.008605                0.000845
# 3                        0.0                -0.011262                0.000682
# 4                        0.0                -0.012311               -0.000253
# ...                      ...                      ...                     ...
# 1115                     0.0                 0.000239                0.000105
# 1116                     0.0                 0.000281                0.000091
# 1117                     0.0                -0.000338               -0.000194
# 1118                     0.0                 0.000222                0.000184
# 1119                     0.0                -0.000322                0.000238
#
#       YearRemodAdd_contribution       model  LinearReg.
# 0                      0.000220  CordAscent         NaN
# 1                      0.001189  CordAscent         NaN
# 2                      0.000419  CordAscent         NaN
# 3                      0.001220  CordAscent         NaN
# 4                      0.001281  CordAscent         NaN
# ...                         ...         ...         ...
# 1115                  -0.000246     RankNet         NaN
# 1116                   0.000715     RankNet         NaN
# 1117                  -0.000166     RankNet         NaN
# 1118                   0.000888     RankNet         NaN
# 1119                   0.000734     RankNet         NaN
#
# [10080 rows x 85 columns]

# %%
merged.to_csv('house_lime.csv',index=False)
