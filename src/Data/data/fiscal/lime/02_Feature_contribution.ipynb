# %%
import pandas as pd
import glob

# %%
a=["CordAscent","LambdaMART","LambdaRank","LinearReg","ListNet","MART","RandomFor","RankBoost","RankNet"]
b=[
"./chart1_data.csv",
"./chart2_data.csv",
"./chart3_data.csv",
"./chart4_data.csv",
"./chart5_data.csv",
"./chart6_data.csv",
"./chart7_data.csv",
"./chart8_data.csv",
"./chart9_data.csv",
]

# %%
temp=[]
for i in range(9):   
    try:
        df=pd.read_csv(b[i],index_col=0)
        df['model']=a[i]
        temp.append(df)
    except:
        print(i)
# Out:
# 4

# %%
merged=pd.concat(temp);

# %% [markdown]
# # Remove extra columns

# %%
for j in merged.columns:
    if "feature_rank" in j:
        merged.drop(j,axis=1,inplace=True)

# %%
for j in merged.columns:
    if j in a:
        merged.drop(j,axis=1,inplace=True)

# %%
merged.columns
# Out:
# Index(['1-qid', 'two_realRank', 'two_realRank2', 'State', 'C_CE_I', 'C_CE_I_R',
#        'Total_Current_Assets', 'Current_Liabilities', 'NonCurrent_Liabilities',
#        'Unrestricted_Net_Assets', 'Restricted_Net_Assets', 'Total_Net_Assets',
#        'Total_Assets', 'Total_Liabilities', 'Total_Taxes', 'Total_Revenue_',
#        'Total_Expenses', 'NonCurrent_Liability', 'Change_in_Net_Assets',
#        'Population', 'UAAL_pension_(risk-free)', 'UAAL_OPEB',
#        'Primary_gov_debt', 'Personal_income', 'cash_ratio', 'quick_ratio',
#        'current_ratio', 'op_ratio', 'surplus_percap', 'net_asst_ratio',
#        'long_term_liab', 'lt_percapita', 'tax_income_ratio',
#        'rev_income_ratio', 'exp_income_ratio', 'pension_income_ratio',
#        'opeb_income_ratio', 'overallrank', 'C_CE_I_R_contribution',
#        'Change_in_Net_Assets_contribution', 'Current_Liabilities_contribution',
#        'NonCurrent_Liability_contribution',
#        'NonCurrent_Liabilities_contribution', 'Personal_income_contribution',
#        'Population_contribution', 'Primary_gov_debt_contribution',
#        'Restricted_Net_Assets_contribution', 'Total_Assets_contribution',
#        'Total_Current_Assets_contribution', 'Total_Expenses_contribution',
#        'Total_Liabilities_contribution', 'Total_Net_Assets_contribution',
#        'Total_Revenue__contribution', 'Total_Taxes_contribution',
#        'UAAL_OPEB_contribution', 'UAAL_pension_(risk-free)_contribution',
#        'Unrestricted_Net_Assets_contribution', 'cash_ratio_contribution',
#        'current_ratio_contribution', 'exp_income_ratio_contribution',
#        'long_term_liab_contribution', 'lt_percapita_contribution',
#        'net_asst_ratio_contribution', 'op_ratio_contribution',
#        'opeb_income_ratio_contribution', 'pension_income_ratio_contribution',
#        'quick_ratio_contribution', 'rev_income_ratio_contribution',
#        'surplus_percap_contribution', 'tax_income_ratio_contribution',
#        'model'],
#       dtype='object')

# %%
merged
# Out:
#      1-qid  two_realRank  two_realRank2          State    C_CE_I  C_CE_I_R  \
# 0     2006             3              3        Alabama   8833844   9839963
# 1     2006             1              1         Alaska  48256838  49666750
# 2     2006            22             22        Arizona   5963508   7059144
# 3     2006            24             24       Arkansas   4186876   5558567
# 4     2006            41             41     California  42340898  55095108
# ..     ...           ...            ...            ...       ...       ...
# 545   2016            13             13       Virginia   8475164  12197635
# 546   2016            30             30     Washington  14272915  21969512
# 547   2016            43             43  West Virginia   4608808   5554682
# 548   2016            26             26      Wisconsin   7462164  14621020
# 549   2016             6              6        Wyoming  21279736  22443933
#
#      Total_Current_Assets  Current_Liabilities  NonCurrent_Liabilities  \
# 0                10964798              1916890                 1892574
# 1                60320527             13015899                 2009314
# 2                 7771343              3211195                 7415246
# 3                 5779994              1517469                 4475565
# 4                70520010             43461846               113661039
# ..                    ...                  ...                     ...
# 545              12642632              5482025                14416557
# 546              26576850             10721110                59533467
# 547               6441716              3616686                 7679538
# 548              14824487              8425200                14959462
# 549              23085998              2955972                 2335713
#
#      Unrestricted_Net_Assets  ...  lt_percapita_contribution  \
# 0                     788480  ...                   0.002620
# 1                    9380565  ...                  -0.000951
# 2                    1173256  ...                   0.002210
# 3                    3022929  ...                   0.003175
# 4                  -62987551  ...                  -0.000087
# ..                       ...  ...                        ...
# 545                 -5051242  ...                  -0.000002
# 546                -11415001  ...                   0.000007
# 547                 -4361160  ...                   0.000008
# 548                 -7860350  ...                  -0.000002
# 549                  4765994  ...                   0.000006
#
#      net_asst_ratio_contribution  op_ratio_contribution  \
# 0                   3.568680e-04           6.481762e-03
# 1                   1.526446e-03           4.509473e-03
# 2                   1.469860e-04           6.435613e-03
# 3                  -1.379354e-03          -2.451242e-03
# 4                  -1.782875e-03          -8.175540e-04
# ..                           ...                    ...
# 545                -3.300000e-06          -1.700000e-06
# 546                 1.600000e-06          -7.000000e-08
# 547                -4.300000e-06           5.200000e-06
# 548                 2.800000e-07          -8.500000e-07
# 549                 2.300000e-06           1.100000e-05
#
#      opeb_income_ratio_contribution  pension_income_ratio_contribution  \
# 0                      5.090000e-05                      -1.229136e-03
# 1                     -8.365080e-04                       3.247556e-03
# 2                     -4.052900e-03                      -1.160264e-03
# 3                     -1.117759e-03                      -4.062174e-03
# 4                     -6.375560e-04                      -3.590387e-03
# ..                              ...                                ...
# 545                    5.000000e-07                      -4.900000e-06
# 546                    1.800000e-06                      -4.300000e-07
# 547                    1.300000e-07                      -2.600000e-05
# 548                   -7.400000e-07                       5.700000e-06
# 549                    1.100000e-06                      -2.500000e-05
#
#      quick_ratio_contribution  rev_income_ratio_contribution  \
# 0                1.384841e-03                   3.450268e-03
# 1                3.819701e-03                   1.303260e-03
# 2               -1.831613e-03                  -2.267649e-03
# 3                1.592864e-03                  -5.655430e-04
# 4               -1.792585e-03                   6.653480e-04
# ..                        ...                            ...
# 545             -3.300000e-07                   6.400000e-06
# 546             -5.100000e-07                  -3.200000e-07
# 547              7.500000e-07                  -1.100000e-05
# 548             -1.800000e-06                   9.200000e-07
# 549             -1.800000e-06                   2.900000e-08
#
#      surplus_percap_contribution  tax_income_ratio_contribution       model
# 0                   1.328791e-02                   1.428971e-03  CordAscent
# 1                   9.251938e-03                  -2.430405e-03  CordAscent
# 2                   6.844139e-03                  -2.543447e-03  CordAscent
# 3                   1.218421e-02                  -7.874360e-04  CordAscent
# 4                  -1.406363e-03                  -9.308490e-04  CordAscent
# ..                           ...                            ...         ...
# 545                -4.700000e-06                   5.700000e-06     RankNet
# 546                 5.700000e-07                   4.600000e-06     RankNet
# 547                -9.700000e-09                  -3.100000e-06     RankNet
# 548                 7.100000e-07                   3.300000e-06     RankNet
# 549                -1.700000e-06                  -6.700000e-07     RankNet
#
# [4400 rows x 71 columns]

# %%
merged.to_csv('fiscal_lime.csv',index=False)
