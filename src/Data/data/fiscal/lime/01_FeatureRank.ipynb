# %%
import pandas as pd
import glob

# %%
a=["CordAscent","LambdaMART","LambdaRank","LinearReg","ListNet","MART","RandomFor","RankBoost","RankNet"]
b=[
"./chart1_data.csv",
"./chart2_data.csv",
"./chart3_data.csv",
"./chart4_data.csv",
"./chart5_data.csv",
"./chart6_data.csv",
"./chart7_data.csv",
"./chart8_data.csv",
"./chart9_data.csv",
]

# %%
temp=[]
for i in range(9):   
    try:
        df=pd.read_csv(b[i],index_col=0)
        df['model']=a[i]
        temp.append(df)
    except:
        print(i)
# Out:
# 4

# %%
merged=pd.concat(temp);
# Out:
# E:\00_Installed_programs\anaconda\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Remove extra columns

# %%
import pandas as pd
import glob

# %%
for j in merged.columns:
    if "feature_rank" not in j and "1-qid" not in j and "model" not in j:
        merged.drop(j,axis=1,inplace=True)

# %%
merged
# Out:
#      1-qid  C_CE_I_R_feature_rank  Change_in_Net_Assets_feature_rank  \
# 0     2006                     27                                 20
# 1     2006                      9                                 19
# 2     2006                     33                                 26
# 3     2006                     24                                 33
# 4     2006                     32                                 22
# ..     ...                    ...                                ...
# 545   2016                     12                                 29
# 546   2016                      4                                 21
# 547   2016                     10                                 29
# 548   2016                      2                                 10
# 549   2016                      2                                 20
#
#      Current_Liabilities_feature_rank  NonCurrent_Liabilities_feature_rank  \
# 0                                  24                                    1
# 1                                  10                                    2
# 2                                  19                                    1
# 3                                  10                                    1
# 4                                  19                                    1
# ..                                ...                                  ...
# 545                                17                                   15
# 546                                 2                                    9
# 547                                 7                                   18
# 548                                 1                                   18
# 549                                14                                   18
#
#      NonCurrent_Liability_feature_rank  Personal_income_feature_rank  \
# 0                                   12                             5
# 1                                   21                             6
# 2                                    9                            10
# 3                                   32                             5
# 4                                   12                             6
# ..                                 ...                           ...
# 545                                 23                             5
# 546                                 14                            15
# 547                                 27                            17
# 548                                 26                            22
# 549                                 19                            22
#
#      Population_feature_rank  Primary_gov_debt_feature_rank  \
# 0                         16                              4
# 1                         23                              5
# 2                         16                              6
# 3                         25                             20
# 4                          9                              4
# ..                       ...                            ...
# 545                        2                             28
# 546                        7                             12
# 547                        3                             11
# 548                       19                              4
# 549                        7                             17
#
#      Restricted_Net_Assets_feature_rank  ...  lt_percapita_feature_rank  \
# 0                                    13  ...                         11
# 1                                    22  ...                         28
# 2                                    32  ...                         15
# 3                                    14  ...                         13
# 4                                    24  ...                         33
# ..                                  ...  ...                        ...
# 545                                   9  ...                         22
# 546                                   6  ...                         18
# 547                                  13  ...                          9
# 548                                   3  ...                         23
# 549                                   4  ...                         16
#
#           model  net_asst_ratio_feature_rank  op_ratio_feature_rank  \
# 0    CordAscent                           28                      6
# 1    CordAscent                           26                     11
# 2    CordAscent                           30                      4
# 3    CordAscent                           19                     15
# 4    CordAscent                           21                     27
# ..          ...                          ...                    ...
# 545     RankNet                           19                     24
# 546     RankNet                           25                     33
# 547     RankNet                           19                     16
# 548     RankNet                           33                     28
# 549     RankNet                           25                     10
#
#      opeb_income_ratio_feature_rank  pension_income_ratio_feature_rank  \
# 0                                32                                 19
# 1                                29                                 17
# 2                                 7                                 23
# 3                                23                                  9
# 4                                30                                 13
# ..                              ...                                ...
# 545                              30                                 13
# 546                              24                                 30
# 547                              32                                  1
# 548                              30                                 12
# 549                              28                                  3
#
#      quick_ratio_feature_rank  rev_income_ratio_feature_rank  \
# 0                          18                              9
# 1                          16                             27
# 2                          17                             14
# 3                          18                             31
# 4                          20                             29
# ..                        ...                            ...
# 545                        31                              6
# 546                        29                             32
# 547                        31                              4
# 548                        24                             27
# 549                        26                             33
#
#      surplus_percap_feature_rank  tax_income_ratio_feature_rank
# 0                              3                             17
# 1                              4                             20
# 2                              3                             13
# 3                              2                             28
# 4                             23                             25
# ..                           ...                            ...
# 545                           14                              8
# 546                           28                             22
# 547                           33                             23
# 548                           31                             17
# 549                           27                             30
#
# [4400 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['1-qid', 'two_realRank', 'two_realRank2', 'State', 'RankNet', 'C_CE_I',
#        'C_CE_I_R', 'Total_Current_Assets', 'Current_Liabilities',
#        'NonCurrent_Liabilities',
#        ...
#        'lt_percapita_feature_rank', 'net_asst_ratio_feature_rank',
#        'op_ratio_feature_rank', 'opeb_income_ratio_feature_rank',
#        'pension_income_ratio_feature_rank', 'quick_ratio_feature_rank',
#        'rev_income_ratio_feature_rank', 'surplus_percap_feature_rank',
#        'tax_income_ratio_feature_rank', 'model'],
#       dtype='object', length=104)

# %%
merged.to_csv('fiscal_rank.csv',index=False)
