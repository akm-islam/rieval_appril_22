# %%
import pandas as pd
import glob

# %%
a=["CordAscent","LambdaMART","LambdaRank","LinearReg","ListNet","MART","RandomFor","RankBoost","RankNet"]
b=[
"./chart1_data.csv",
"./chart2_data.csv",
"./chart3_data.csv",
"./chart4_data.csv",
"./chart5_data.csv",
"./chart6_data.csv",
"./chart7_data.csv",
"./chart8_data.csv",
"./chart9_data.csv",
]

# %%
temp=[]
for i in range(9):   
    try:
        df=pd.read_csv(b[i],index_col=0)
        df['model']=a[i]
        temp.append(df)
    except:
        print(i)
# Out:
# 4

# %%
merged=pd.concat(temp);

# %% [markdown]
# # Remove extra columns

# %%
import pandas as pd
import glob

# %%
for j in merged.columns:
    if "feature_rank" not in j and "1-qid" not in j and "model" not in j:
        merged.drop(j,axis=1,inplace=True)

# %%
merged
# Out:
#       1-qid  country_feature_rank  female_percent_feature_rank  \
# 0      2011                     3                            7
# 1      2011                     7                            8
# 2      2011                     4                            7
# 3      2011                     4                            8
# 4      2011                     2                            5
# ...     ...                   ...                          ...
# 2598   2016                     1                            9
# 2599   2016                     1                            9
# 2600   2016                     1                            9
# 2601   2016                     4                           10
# 2602   2016                     7                           10
#
#       income_feature_rank  international_feature_rank  \
# 0                       1                           2
# 1                       1                           2
# 2                       8                           1
# 3                       7                           2
# 4                       7                           4
# ...                   ...                         ...
# 2598                    6                           3
# 2599                    6                           3
# 2600                    6                           3
# 2601                    6                           7
# 2602                    6                           8
#
#       international_students_feature_rank  num_students_feature_rank  \
# 0                                      10                          9
# 1                                      10                          3
# 2                                       9                          3
# 3                                      10                          5
# 4                                       8                         10
# ...                                   ...                        ...
# 2598                                   10                          7
# 2599                                   10                          7
# 2600                                   10                          7
# 2601                                    1                          2
# 2602                                    4                          9
#
#       research_feature_rank  student_staff_ratio_feature_rank  \
# 0                         5                                 4
# 1                         9                                 4
# 2                        10                                 2
# 3                         6                                 9
# 4                         9                                 1
# ...                     ...                               ...
# 2598                      4                                 8
# 2599                      4                                 8
# 2600                      4                                 8
# 2601                      3                                 8
# 2602                      5                                 2
#
#       teaching_feature_rank       model
# 0                         8  CordAscent
# 1                         5  CordAscent
# 2                         5  CordAscent
# 3                         1  CordAscent
# 4                         6  CordAscent
# ...                     ...         ...
# 2598                      2     RankNet
# 2599                      2     RankNet
# 2600                      2     RankNet
# 2601                      5     RankNet
# 2602                      3     RankNet
#
# [20824 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['1-qid', 'two_realRank', 'two_realRank2', 'State', 'RankNet', 'country',
#        'teaching', 'international', 'research', 'citations', 'income',
#        'total_score', 'num_students', 'student_staff_ratio', 'year',
#        'female_percent', 'international_students', 'world_rank',
#        'country_encoded', 'country_contribution',
#        'female_percent_contribution', 'income_contribution',
#        'international_contribution', 'international_students_contribution',
#        'num_students_contribution', 'research_contribution',
#        'student_staff_ratio_contribution', 'teaching_contribution',
#        'country_feature_rank', 'female_percent_feature_rank',
#        'income_feature_rank', 'international_feature_rank',
#        'international_students_feature_rank', 'num_students_feature_rank',
#        'research_feature_rank', 'student_staff_ratio_feature_rank',
#        'teaching_feature_rank', 'model'],
#       dtype='object')

# %%
merged.to_csv('rank_school.csv',index=False)
