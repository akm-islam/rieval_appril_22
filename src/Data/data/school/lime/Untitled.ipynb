# %%
import pandas as pd

# %%
data=pd.read_csv('school_lime.csv')

# %%
data
# Out:
#        1-qid  two_realRank  two_realRank2  \
# 0       2011           167          167.0
# 1       2011           147          147.0
# 2       2011           162          161.0
# 3       2011            43           43.0
# 4       2011           173          173.0
# ...      ...           ...            ...
# 20819   2016            48           54.0
# 20820   2016           150          201.0
# 20821   2016           739            NaN
# 20822   2016            31           31.0
# 20823   2016           219          301.0
#
#                                           State      country  teaching  \
# 0                             Aarhus University      Denmark      38.1
# 1                         Alexandria University        Egypt      29.5
# 2                      Arizona State University          USA      43.0
# 3                Australian National University    Australia      51.9
# 4                          Bielefeld University      Germany      39.9
# ...
